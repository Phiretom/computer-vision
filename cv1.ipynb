# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
arr = np.random.randint(0, 10, (5, 5))
print(arr)
# Out:
# [[2 6 1 1 1]
#  [1 7 9 1 1]
#  [0 1 2 3 7]
#  [1 7 0 1 1]
#  [8 4 2 0 6]]

# %%
print(arr.T)
# Out:
# [[2 1 0 1 8]
#  [6 7 1 7 4]
#  [1 9 2 0 2]
#  [1 1 3 1 0]
#  [1 1 7 1 6]]

# %%
print(np.sum(arr))
# Out:
# 73

# %%
print(np.mean(arr))
# Out:
# 2.92

# %%
print(np.max(arr))
print(np.min(arr))
# Out:
# 9
# 0

# %%
print(arr * 2)
# Out:
# [[ 4 12  2  2  2]
#  [ 2 14 18  2  2]
#  [ 0  2  4  6 14]
#  [ 2 14  0  2  2]
#  [16  8  4  0 12]]

# %%
print(np.argmax(arr))
print(np.argmin(arr))
# Out:
# 7
# 10

# %%
img = cv2.imread("flowers.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(295.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(295.5), np.float64(-0.5))

# %%
edges = cv2.Canny(gray, 100, 200)

plt.imshow(edges, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(295.5), np.float64(-0.5))

# %%
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
img_contours = img_rgb.copy()
cv2.drawContours(img_contours, contours, -1, (255,0,0), 2)

plt.imshow(img_contours)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(295.5), np.float64(-0.5))

# %%
def my_rectangle(image, pt1, pt2, color=(255,0,0)):
    img = image.copy()
    
    x1, y1 = pt1
    x2, y2 = pt2
    
    img[y1, x1:x2] = color
    img[y2, x1:x2] = color
    img[y1:y2, x1] = color
    img[y1:y2, x2] = color
    
    return img

# %%
test_img = img_rgb.copy()
result = my_rectangle(test_img, (50,50), (200,200), (255,0,0))

plt.imshow(result)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(473.5), np.float64(295.5), np.float64(-0.5))
